# %%
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as T
import torch
import torch.nn as nn
from torchvision.utils import make_grid
from torchvision.utils import save_image
from IPython.display import Image
import matplotlib.pyplot as plt
import numpy as np
import random
from torchvision.io import read_image
import os
# %matplotlib inline

# %%
PATH_IMG = '../data/train_images_processed_512/'
PATH_META = '../data/train-3.csv'

# %%
import pandas as pd

df = pd.read_csv(PATH_META, sep=',', header=None)

# %%
df.describe()
# Out:
#            0      1         2      3      4      5      6      7      8   \
# count   54707  54707     54707  54707  54707  54670  54707  54707  54707
# unique      3  11914     54707      3      7     64      3      3      3
# top         1  52868  image_id      R    MLO     50      0      0      0
# freq    29519     14         1  27439  27903   2248  53548  51737  53888
#
#            9      10     11     12     13
# count   26287  54707  29471  54707  54707
# unique      4      3      5     11      3
# top         1      0      B     49  False
# freq    15772  53229  12651  23529  47001

# %%
df.columns = df.iloc[0,:]
df = df.drop(index = 0)
df[14] = df.image_id

# %%
missing_values_count = df.isnull().sum()


missing_values_count[0:15]
# Out:
# 0
# site_id                        0
# patient_id                     0
# image_id                       0
# laterality                     0
# view                           0
# age                           37
# cancer                         0
# biopsy                         0
# invasive                       0
# BIRADS                     28420
# implant                        0
# density                    25236
# machine_id                     0
# difficult_negative_case        0
# 14                             0
# dtype: int64

# %%
df
# Out:
# 0     site_id patient_id    image_id laterality view age cancer biopsy  \
# 1           2      10006   462822612          L   CC  61      0      0
# 2           2      10006  1459541791          L  MLO  61      0      0
# 3           2      10006  1864590858          R  MLO  61      0      0
# 4           2      10006  1874946579          R   CC  61      0      0
# 5           2      10011   220375232          L   CC  55      0      0
# ...       ...        ...         ...        ...  ...  ..    ...    ...
# 54702       1       9973  1729524723          R  MLO  43      0      0
# 54703       1       9989    63473691          L  MLO  60      0      0
# 54704       1       9989  1078943060          L   CC  60      0      0
# 54705       1       9989   398038886          R  MLO  60      0      0
# 54706       1       9989   439796429          R   CC  60      0      0
#
# 0     invasive BIRADS implant density machine_id difficult_negative_case  \
# 1            0    NaN       0     NaN         29                   False
# 2            0    NaN       0     NaN         29                   False
# 3            0    NaN       0     NaN         29                   False
# 4            0    NaN       0     NaN         29                   False
# 5            0      0       0     NaN         21                    True
# ...        ...    ...     ...     ...        ...                     ...
# 54702        0      1       0       C         49                   False
# 54703        0    NaN       0       C        216                   False
# 54704        0    NaN       0       C        216                   False
# 54705        0      0       0       C        216                    True
# 54706        0      0       0       C        216                    True
#
# 0              14
# 1       462822612
# 2      1459541791
# 3      1864590858
# 4      1874946579
# 5       220375232
# ...           ...
# 54702  1729524723
# 54703    63473691
# 54704  1078943060
# 54705   398038886
# 54706   439796429
#
# [54706 rows x 15 columns]

# %%
# Convert object to int where we don't have missing value
list_to_num = ['site_id', 'patient_id', 'image_id', 'cancer', 'biopsy','invasive','implant','machine_id',14]
for i in list_to_num:
    df[i] = df[i].astype(int)
# Convert object to float where we have missing value
df['age'] = df['age'].astype('float')
df['BIRADS'] = df['BIRADS'].astype('float')
df['difficult_negative_case'] = df['difficult_negative_case'].astype('bool')

# %%
df.set_index('image_id')
# Out:
# 0           site_id  patient_id laterality view   age  cancer  biopsy  \
# image_id
# 462822612         2       10006          L   CC  61.0       0       0
# 1459541791        2       10006          L  MLO  61.0       0       0
# 1864590858        2       10006          R  MLO  61.0       0       0
# 1874946579        2       10006          R   CC  61.0       0       0
# 220375232         2       10011          L   CC  55.0       0       0
# ...             ...         ...        ...  ...   ...     ...     ...
# 1729524723        1        9973          R  MLO  43.0       0       0
# 63473691          1        9989          L  MLO  60.0       0       0
# 1078943060        1        9989          L   CC  60.0       0       0
# 398038886         1        9989          R  MLO  60.0       0       0
# 439796429         1        9989          R   CC  60.0       0       0
#
# 0           invasive  BIRADS  implant density  machine_id  \
# image_id
# 462822612          0     NaN        0     NaN          29
# 1459541791         0     NaN        0     NaN          29
# 1864590858         0     NaN        0     NaN          29
# 1874946579         0     NaN        0     NaN          29
# 220375232          0     0.0        0     NaN          21
# ...              ...     ...      ...     ...         ...
# 1729524723         0     1.0        0       C          49
# 63473691           0     NaN        0       C         216
# 1078943060         0     NaN        0       C         216
# 398038886          0     0.0        0       C         216
# 439796429          0     0.0        0       C         216
#
# 0           difficult_negative_case          14
# image_id
# 462822612                      True   462822612
# 1459541791                     True  1459541791
# 1864590858                     True  1864590858
# 1874946579                     True  1874946579
# 220375232                      True   220375232
# ...                             ...         ...
# 1729524723                     True  1729524723
# 63473691                       True    63473691
# 1078943060                     True  1078943060
# 398038886                      True   398038886
# 439796429                      True   439796429
#
# [54706 rows x 14 columns]

# %%
df.dtypes
# Out:
# 0
# site_id                      int64
# patient_id                   int64
# image_id                     int64
# laterality                  object
# view                        object
# age                        float64
# cancer                       int64
# biopsy                       int64
# invasive                     int64
# BIRADS                     float64
# implant                      int64
# density                     object
# machine_id                   int64
# difficult_negative_case       bool
# 14                           int64
# dtype: object

# %%
# Fill missing value in age
df['age'] = df['age'].fillna(df['age'].mean())

# %%
# Fill missing value in density
temp = pd.DataFrame(df['density'])

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp_mean.fit(temp)
new_temp = imp_mean.transform(temp)
np.squeeze(new_temp, axis=1)
df['density'] = new_temp

# %%
# Fill missing value in BIRADS by most frequent value
df['BIRADS'] = df['BIRADS'].fillna(int(df['BIRADS'].mode()))

# %%
missing_values_count = df.isnull().sum()


missing_values_count[0:15]
# Out:
# 0
# site_id                    0
# patient_id                 0
# image_id                   0
# laterality                 0
# view                       0
# age                        0
# cancer                     0
# biopsy                     0
# invasive                   0
# BIRADS                     0
# implant                    0
# density                    0
# machine_id                 0
# difficult_negative_case    0
# 14                         0
# dtype: int64

# %% [markdown]
# image_id	laterality	view   density

# %%
list_col = ['laterality','view','density']
for i in list_col:
    print(df[i].value_counts())
# Out:
# R    27439
# L    27267
# Name: laterality, dtype: int64
# MLO    27903
# CC     26765
# AT        19
# LM        10
# ML         8
# LMO        1
# Name: view, dtype: int64
# B    37887
# C    12175
# A     3105
# D     1539
# Name: density, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

list_col = ['laterality','view','density']
for i in list_col:
    education_column = df[[i]]
    encoder = OrdinalEncoder()
    df[i] = encoder.fit_transform(education_column)

# %%
df.describe()
# Out:
# 0           site_id    patient_id      image_id    laterality          view  \
# count  54706.000000  54706.000000  5.470600e+04  54706.000000  54706.000000
# mean       1.460407  32698.865262  1.079386e+09      0.501572      3.040526
# std        0.498434  18893.861534  6.183269e+08      0.500002      1.999777
# min        1.000000      5.000000  6.849100e+04      0.000000      0.000000
# 25%        1.000000  16481.000000  5.458153e+08      0.000000      1.000000
# 50%        1.000000  32432.000000  1.082689e+09      1.000000      5.000000
# 75%        2.000000  48999.000000  1.613228e+09      1.000000      5.000000
# max        2.000000  65534.000000  2.147472e+09      1.000000      5.000000
#
# 0               age        cancer        biopsy      invasive        BIRADS  \
# count  54706.000000  54706.000000  54706.000000  54706.000000  54706.000000
# mean      58.543928      0.021168      0.054272      0.014953      0.890615
# std       10.047484      0.143944      0.226556      0.121365      0.424534
# min       26.000000      0.000000      0.000000      0.000000      0.000000
# 25%       51.000000      0.000000      0.000000      0.000000      1.000000
# 50%       59.000000      0.000000      0.000000      0.000000      1.000000
# 75%       66.000000      0.000000      0.000000      0.000000      1.000000
# max       89.000000      1.000000      1.000000      1.000000      2.000000
#
# 0           implant       density    machine_id            14
# count  54706.000000  54706.000000  54706.000000  5.470600e+04
# mean       0.026999      1.222060     54.618378  1.079386e+09
# std        0.162081      0.585266     44.784800  6.183269e+08
# min        0.000000      0.000000     21.000000  6.849100e+04
# 25%        0.000000      1.000000     29.000000  5.458153e+08
# 50%        0.000000      1.000000     49.000000  1.082689e+09
# 75%        0.000000      2.000000     49.000000  1.613228e+09
# max        1.000000      3.000000    216.000000  2.147472e+09

# %%
list_col = ['laterality','view','density']
for i in list_col:
    print(df[i].value_counts())
# Out:
# 1.0    27439
# 0.0    27267
# Name: laterality, dtype: int64
# 5.0    27903
# 1.0    26765
# 0.0       19
# 2.0       10
# 4.0        8
# 3.0        1
# Name: view, dtype: int64
# 1.0    37887
# 2.0    12175
# 0.0     3105
# 3.0     1539
# Name: density, dtype: int64
